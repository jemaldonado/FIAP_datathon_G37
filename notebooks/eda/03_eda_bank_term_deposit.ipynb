# %% [markdown]
# # EDA — Bank Term Deposit Subscription
#
# **Source**: dharmik34/bank-term-deposit-subscription
# **Role**: Comparison — term deposit subscription as proxy conversion signal
#
# Run ETL first: `python -m datathon.etl.bank_term_deposit`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

sns.set_theme(style='whitegrid')
DATA = Path('../../data')

# %% [markdown]
# ## 1. Shape and Schema

# %%
df = pd.read_parquet(DATA / 'processed/bank_term_deposit.parquet')
print(f'Shape: {df.shape}')
df.dtypes

# %%
df.head()

# %% [markdown]
# ## 2. Missing Values

# %%
missing = df.isnull().sum()
missing[missing > 0].sort_values(ascending=False)

# %% [markdown]
# ## 3. Target Distribution

# %%
target_col = next((c for c in df.columns if c.lower() in ('y', 'subscribed', 'target')), None)
if target_col:
    fig, ax = plt.subplots()
    df[target_col].value_counts().plot(kind='bar', ax=ax)
    ax.set_title(f'Target distribution ({target_col})')
    plt.tight_layout()
    plt.show()
    print(df[target_col].value_counts(normalize=True))

# %% [markdown]
# ## 4. Numeric Feature Distributions

# %%
num_cols = df.select_dtypes(include='number').columns.tolist()
if target_col in num_cols:
    num_cols = [c for c in num_cols if c != target_col]
df[num_cols].hist(bins=30, figsize=(16, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Categorical Feature Distributions

# %%
cat_cols = df.select_dtypes(include='object').columns.tolist()
for col in cat_cols:
    fig, ax = plt.subplots(figsize=(8, 3))
    df[col].value_counts().plot(kind='bar', ax=ax)
    ax.set_title(col)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 6. Correlation Heatmap (Numeric Features)

# %%
fig, ax = plt.subplots(figsize=(12, 10))
corr_cols = num_cols + ([target_col] if target_col else [])
sns.heatmap(df[corr_cols].corr(), annot=True, fmt='.2f', ax=ax)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Conversion Rate by Categorical Feature

# %%
if target_col:
    for col in cat_cols:
        rates = df.groupby(col)[target_col].mean().sort_values(ascending=False)
        fig, ax = plt.subplots(figsize=(8, 3))
        rates.plot(kind='bar', ax=ax)
        ax.set_title(f'Conversion rate by {col}')
        ax.set_ylabel(f'P({target_col}=1)')
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ## 8. Leakage Audit

# %%
leakage_cols = ['duration']
present = [c for c in leakage_cols if c in df.columns]
if present:
    print(f'WARNING: leakage columns present: {present}')
else:
    print('OK: no leakage columns found in processed dataset')

# %% [markdown]
# ## 9. Summary
#
# | Metric | Value |
# |--------|-------|
# | Rows | — |
# | Columns (post-ETL) | — |
# | Conversion rate | — |
# | Missing values | — |
# | Leakage columns dropped | `duration` |
#
# > Fill in after running notebook.
